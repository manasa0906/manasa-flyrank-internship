# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/manasa0906/manasa-flyrank-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# *Task type: Scoring*
#
# My lane is CTR / Engagement Opportunity Scoring. I frame this as a scoring problem because the goal is to give each content item an opportunity score based on its expected engagement potential. The score can help identify and prioritize content that may benefit from improvement rather than simply classifying pages as good or bad.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# data/raw/content_refresh_anonymized.csv

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# **Success metric: Mean Absolute Error (MAE).**
#
# I would use MAE to measure how close the predicted engagement outcome is to the actual outcome. A lower MAE means the predictions are closer to the observed values, so lower is better. Because the goal is to produce useful opportunity scores for content prioritization, prediction error should be kept as small as possible.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# import pandas as pd
#
# df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
#
# print("Shape:", df.shape)
# print("Columns:")
# print(df.columns.tolist())
#
# df.head()

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule such as "refresh every page below a certain CTR threshold" is too simple because engagement depends on multiple factors, not just one number. Different content items can have different levels of impressions, clicks, and other characteristics. ML can learn patterns across multiple features and produce a more flexible opportunity score. The output supports a real content action: prioritizing which pages the content team should review and refresh first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
